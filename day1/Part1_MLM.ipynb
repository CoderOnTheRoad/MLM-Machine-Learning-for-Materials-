# %% [markdown]
# # Part1: Data Handling

# %% [markdown]
# ## Read and print the data

# %%
import pandas as pd

# %%
# read_and_print_the_dataset
df=pd.read_csv('https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_small.csv')
#df=pd.read_excel('student_data_small.xlsx')

# %%
#print_the_dataset
# type(df)
print(df)
# Out:
#    Roll_Number             Name  Age  Marks
# 0          101    Alice Johnson   19     85
# 1          102        Bob Smith   20     78
# 2          103    Charlie Brown   21     92
# 3          104   David Williams   19     74
# 4          105      Emily Davis   22     88
# 5          106     Frank Miller   20     81
# 6          107     Grace Wilson   21     95
# 7          108      Henry Moore   19     67
# 8          109  Isabella Taylor   20     79
# 9          110    Jack Anderson   21     83

# %% [markdown]
# ## Visualize the dataset

# %% [markdown]
# ![Untitled Notebook-3.jpg](data:image/jpeg;base64,...)

# %%
#describe the dataset
df.describe()
# Out:
#        Roll_Number        Age      Marks
# count     10.00000  10.000000  10.000000
# mean     105.50000  20.200000  82.200000
# std        3.02765   1.032796   8.363944
# min      101.00000  19.000000  67.000000
# 25%      103.25000  19.250000  78.250000
# 50%      105.50000  20.000000  82.000000
# 75%      107.75000  21.000000  87.250000
# max      110.00000  22.000000  95.000000

# %%
#shape_of_the_data
print(df.shape)
print(df.size)
print(len(df))
# Out:
# (10, 4)
# 40
# 10

# %%
#view_the_column_names
print(df.columns)
#pick_specific_column_and_print
print(df['Age'] - df['Age'].mean())
# Out:
# Index(['Roll_Number', 'Name', 'Age', 'Marks'], dtype='object')
# 0   -1.2
# 1   -0.2
# 2    0.8
# 3   -1.2
# 4    1.8
# 5   -0.2
# 6    0.8
# 7   -1.2
# 8   -0.2
# 9    0.8
# Name: Age, dtype: float64

# %% [markdown]
# ## Interacting with the rows

# %%
#print_specific_row_element

#method1: using .iloc
print(df.iloc[0]['Name'])#.to_list())
# Out:
# Alice Johnson

# %%
# method2: Using a list of column names using .loc
row_index = 0
columns_to_print = df.columns
print(df.loc[row_index, columns_to_print])
# Out:
# Roll_Number              101
# Name           Alice Johnson
# Age                       19
# Marks                     85
# Name: 0, dtype: object

# %%
# method3: Using .values to get a NumPy array representation of the row
row_index = 0
row_as_array = df.iloc[row_index].values
print(row_as_array)
# Out:
# [101 'Alice Johnson' 19 85]

# %%
# method4: Iterating through the row and printing each value
row_index = 0
for col, value in df.iloc[row_index].items():
  print(f'{col}: {value}')
# Out:
# Roll_Number: 101
# Name: Alice Johnson
# Age: 19
# Marks: 85

# %%
#add_a_new_row_to_the_dataframe
## Method 1: Using loc with a new index label
#new_row = pd.DataFrame({'Age': 25, 'Name': 'Alice', 'Grade': 'A'}, index=[len(df)])
#df = pd.concat([df, new_row])
## Method 2: Using loc with a new index label
df.loc[len(df)] = {'Age': 26, 'Name': 'Bob', 'Grade': 'B'}
## Method 3: Using iloc to add a new row
# new_row_data = [27, 'Charlie', 'C', ' D']  # Data for the new row
# df.loc[len(df)] = new_row_data
df
# Out:
#     Roll_Number             Name  Age  Marks
# 0         101.0    Alice Johnson   19   85.0
# 1         102.0        Bob Smith   20   78.0
# 2         103.0    Charlie Brown   21   92.0
# 3         104.0   David Williams   19   74.0
# 4         105.0      Emily Davis   22   88.0
# 5         106.0     Frank Miller   20   81.0
# 6         107.0     Grace Wilson   21   95.0
# 7         108.0      Henry Moore   19   67.0
# 8         109.0  Isabella Taylor   20   79.0
# 9         110.0    Jack Anderson   21   83.0
# 10          NaN              Bob   26    NaN

# %%
#add_a_new_row_to_the_dataframe
# read_and_print_the_dataset
df=pd.read_csv('https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_small.csv')

## Method 1: Using loc with a new index label
print(len(df))
new_row = pd.DataFrame({'Age': 25, 'Name': 'Alice', 'Grade': 'A'}, index=[len(df)])
df = pd.concat([df, new_row])
print(len(df))
df
df.to_excel('file.xlsx')
# Out:
# 10
# 11

# %%
# read_and_print_the_dataset
df=pd.read_csv('https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_small.csv')

## Method 2: Using loc with a new index label
print(len(df))
df.loc[len(df)] = {'Age': 26, 'Name': 'Bob', 'Grade': 'B'}
print(len(df))
df
# Out:
# 10
# 11
#     Roll_Number             Name  Age  Marks
# 0         101.0    Alice Johnson   19   85.0
# 1         102.0        Bob Smith   20   78.0
# 2         103.0    Charlie Brown   21   92.0
# 3         104.0   David Williams   19   74.0
# 4         105.0      Emily Davis   22   88.0
# 5         106.0     Frank Miller   20   81.0
# 6         107.0     Grace Wilson   21   95.0
# 7         108.0      Henry Moore   19   67.0
# 8         109.0  Isabella Taylor   20   79.0
# 9         110.0    Jack Anderson   21   83.0
# 10          NaN              Bob   26    NaN

# %%
# read_and_print_the_dataset
df=pd.read_csv('https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_small.csv')
print(len(df))
## Method 3: Using iloc to add a new row
new_row_data = [27, 'Charlie', 'C', ' D']  # Data for the new row
df.loc[len(df)] = new_row_data
print(len(df))
df
# Out:
# 10
# 11
#     Roll_Number             Name Age Marks
# 0           101    Alice Johnson  19    85
# 1           102        Bob Smith  20    78
# 2           103    Charlie Brown  21    92
# 3           104   David Williams  19    74
# 4           105      Emily Davis  22    88
# 5           106     Frank Miller  20    81
# 6           107     Grace Wilson  21    95
# 7           108      Henry Moore  19    67
# 8           109  Isabella Taylor  20    79
# 9           110    Jack Anderson  21    83
# 10           27          Charlie   C     D

# %%
# Load your data once again
df=pd.read_csv('https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_small.csv')
# Delete rows based on conditions
# Remove rows where 'Age' is greater than 20
#df = df[df['Age'] <= 21]
#print(df)

# Remove rows where 'Grade' is 'B'
#df = df[df['Grade'] != 'B']
#print(df)

# Remove rows based on index
# Drop the row with index 10
df = df.drop(10)
print(df)

# Drop multiple rows by index
#rows_to_delete = [1, 2]
#df = df.drop(rows_to_delete)
#print(df)

#Remove rows based on multiple conditions using query()
#df = df.query('Age < 20 and Grade == "A"')
#df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-6b7cd8f8d562> in <cell line: 0>()
#      12 # Remove rows based on index
#      13 # Drop the row with index 10
# ---> 14 df = df.drop(10)
#      15 print(df)
#      16
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %% [markdown]
# ## Interacting with the columns

# %%
#ADD_columns
#add a new column named 'City' with default value 'New York'
df['City'] = 'New York'
print(df)

#add a new column named 'Country' with different values
df['Country'] = ['USA', 'Canada', 'UK', 'Australia', 'Germany', 'France','USA', 'Canada', 'UK', 'Australia']
print(df)
df
# Out:
#    Roll_Number             Name  Age  Marks      City
# 0          101    Alice Johnson   19     85  New York
# 1          102        Bob Smith   20     78  New York
# 2          103    Charlie Brown   21     92  New York
# 3          104   David Williams   19     74  New York
# 4          105      Emily Davis   22     88  New York
# 5          106     Frank Miller   20     81  New York
# 6          107     Grace Wilson   21     95  New York
# 7          108      Henry Moore   19     67  New York
# 8          109  Isabella Taylor   20     79  New York
# 9          110    Jack Anderson   21     83  New York
#    Roll_Number             Name  Age  Marks      City    Country
# 0          101    Alice Johnson   19     85  New York        USA
# 1          102        Bob Smith   20     78  New York     Canada
# 2          103    Charlie Brown   21     92  New York         UK
# 3          104   David Williams   19     74  New York  Australia
# ...

# %%
# Delete columns using different methods
#Reload your dataset
# Method 1: Using del
del df['City']
print(df)

# Method 2: Using pop()
country_column = df.pop('Country')
print(df)
print(country_column)

# Method 3: Using drop()
#df = df.drop('Grade', axis=1)
#print(df)

# Method 4: Using drop() with a list of columns
#df = df.drop(['Age', 'Name'], axis=1)
#df

# %% [markdown]
# # Assignment: Basic

# %% [markdown]
# Read the dataset : https://raw.githubusercontent.com/CoderOnTheRoad/MLM-Machine-Learning-for-Materials-/refs/heads/master/day1/student_data_large.csv variable name for the dataset should be 'student'

# %%
#Please do it here

# %% [markdown]
# Print How many rows and columns are there in the dataset from data.shape in the format Rows:nn Columns:nn

# %%
#Please do it here

# %% [markdown]
# Print what are the column names in the student dataframe?

# %%
#Please do it here

# %% [markdown]
# Print the fifth row of the student dataset

# %%
#Please do it here

# %% [markdown]
# print the dataset head. Change the third row to second and second to third and print the head again to show the changes

# %% [markdown]
# Print the 'Marks' column

# %%
#Please do it here

# %% [markdown]
# Calculate the average of the ' Age' column in the student dataframe and print.
# Hint: student[ ].sum() or student[ ].mean()

# %%
#Please do it here

# %% [markdown]
# # Assignment: Advanced

# %% [markdown]
# read the dataset.csv and  print each row using iterative loop and the output should look like -
#
# Row 1:
#
# Roll_Number: 101
#
# Name: Alice Johnson
#
# Age: 19
#
# Marks: 85
#
#
# Row 2:
#
# Roll_Number: 102
#
# Name: Bob Smith
#
# Age: 20
#
# Marks: 78

# %% [markdown]
# Calcute the average of the Marks of the students

# %% [markdown]
# Calcute the the RMS of the Marks of the students

# %% [markdown]
# change the last row to the first row and first row to the last

# %% [markdown]
# Take the Marks column value and create a new column name apass if the value is less than 80 then the pass value will be else it yes
